# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("C:/Users/Asus/Downloads/AB_NYC_2019 (1).csv")

# %%
df.shape
# Out:
# (48906, 16)

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.sample(5)
# Out:
#              id                                            name    host_id  \
# 36135  28722897         Charming Shared Place in East Manhattan  209386156
# 38463  30269942  Cozy, Light and Calming East Village apartment   48666840
# 41088  31952771            Sunny 1 bedroom w/private half bath!   89181972
# 17314  13673873   Beautiful bedroom in ideal Brooklyn location!   78285648
# 30004  23100931      Modern, Sunny 3 Bdrm 2 Ba w/ Huge Backyard    6309691
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 36135   Abraham           Manhattan   East Harlem  40.79912  -73.94202
# 38463      Ryan           Manhattan  East Village  40.72809  -73.98028
# 41088      Lexx               Bronx     Bronxdale  40.85646  -73.86813
# 17314   Sharina            Brooklyn    Kensington  40.63622  -73.97406
# 30004      Lisa            Brooklyn    Greenpoint  40.73384  -73.95782
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
sns.boxplot(df["price"])
# Out:
# <Axes: >

# %% [markdown]
# ## HANDLING NULL VALUES

# %%
df1=df.copy()

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.drop("last_review",axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df2=df.copy()

# %%
df2.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df2.shape
# Out:
# (48895, 16)

# %%
df2.dropna(inplace=True)

# %%
df2.shape
# Out:
# (38821, 16)

# %%
df3=df.copy()

# %%
mean_value=df3["reviews_per_month"].mean()
df3["reviews_per_month"].fillna(mean_value,inplace=True)

# %%
df3
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df3.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df2.nunique()
# Out:
# id                                38821
# name                              38253
# host_id                           30232
# host_name                          9885
# neighbourhood_group                   5
# neighbourhood                       218
# latitude                          17436
# longitude                         13639
# room_type                             3
# price                               581
# minimum_nights                       89
# number_of_reviews                   393
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df3["last_review"].fillna(df3["last_review"].value_counts().index[0])
# Out:
# 0        2018-10-19
# 1        2019-05-21
# 2        2019-06-23
# 3        2019-07-05
# 4        2018-11-19
#             ...
# 48890    2019-06-23
# 48891    2019-06-23
# 48892    2019-06-23
# 48893    2019-06-23
# 48894    2019-06-23
# Name: last_review, Length: 48895, dtype: object

# %%
df4=df.copy()

# %%
df4["last_review"].fillna("Not_Reviewed",inplace=True)

# %%
df4.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
df5=df.copy()

# %%
df5["reviews_per_month"].interpolate(inplace=True)

# %%
df5
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## REMOVING DUPLICATE VALUES

# %%
df.duplicated().sum()
# Out:
# 11

# %%
df[df.duplicated()]
# Out:
#          id                                              name  host_id  \
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 48896  5121                                   BlissArtsSpace!     7356
# 48897  5178                  Large Furnished Room Near B'way      8967
# 48898  5203                Cozy Clean Guest Room - Family Apt     7490
# 48899  5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 48900  5295                  Beautiful 1br on Upper West Side     7702
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
df[df.duplicated(keep="first")]
# Out:
#          id                                              name  host_id  \
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 48896  5121                                   BlissArtsSpace!     7356
# 48897  5178                  Large Furnished Room Near B'way      8967
# 48898  5203                Cozy Clean Guest Room - Family Apt     7490
# 48899  5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 48900  5295                  Beautiful 1br on Upper West Side     7702
# 48901  5441                   Central Manhattan/near Broadway     7989
# 48902  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 48903  6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 48904  6090                     West Village Nest - Superhost    11975
# 48905  6848                  Only 2 stops to Manhattan studio    15991
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
#          id                                              name  host_id  \
# 5      5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6      5121                                   BlissArtsSpace!     7356
# 7      5178                  Large Furnished Room Near B'way      8967
# 8      5203                Cozy Clean Guest Room - Family Apt     7490
# 9      5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10     5295                  Beautiful 1br on Upper West Side     7702
# 11     5441                   Central Manhattan/near Broadway     7989
# 12     5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# 13     6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 14     6090                     West Village Nest - Superhost    11975
# 15     6848                  Only 2 stops to Manhattan studio    15991
# 48895  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# ...

# %%
df.drop_duplicates()
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.duplicated(["id","name"]).sum()
# Out:
# 11

# %%
df=pd.read_csv("C:/Users/Asus/Downloads/AB_NYC_2019 (1).csv")

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48906 entries, 0 to 48905
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48906 non-null  int64
#  1   name                            48890 non-null  object
#  2   host_id                         48906 non-null  int64
#  3   host_name                       48885 non-null  object
#  4   neighbourhood_group             48906 non-null  object
#  5   neighbourhood                   48906 non-null  object
#  6   latitude                        48906 non-null  float64
#  7   longitude                       48906 non-null  float64
#  8   room_type                       48906 non-null  object
#  9   price                           48906 non-null  int64
#  10  minimum_nights                  48906 non-null  int64
#  11  number_of_reviews               48906 non-null  int64
# ...

# %%
df["id"]=df["id"].astype("str")

# %%
df["id"].dtype
# Out:
# dtype('O')

# %%
df["host_id"]=df["host_id"].astype("str")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48906 entries, 0 to 48905
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48906 non-null  object
#  1   name                            48890 non-null  object
#  2   host_id                         48906 non-null  object
#  3   host_name                       48885 non-null  object
#  4   neighbourhood_group             48906 non-null  object
#  5   neighbourhood                   48906 non-null  object
#  6   latitude                        48906 non-null  float64
#  7   longitude                       48906 non-null  float64
#  8   room_type                       48906 non-null  object
#  9   price                           48906 non-null  int64
#  10  minimum_nights                  48906 non-null  int64
#  11  number_of_reviews               48906 non-null  int64
# ...

# %%
df["last_review"]=pd.to_datetime(df["last_review"],dayfirst=True)
