# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("C:/Users/Asus/Downloads/List of Countries by Sugarcane Production.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %%
df["Production (Tons)"]=df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"]=df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"]=df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"]=df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3668531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                    1264303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.rename(columns={"Production (Tons)":"Production(Tons)"},inplace=True)
df.rename(columns={"Production per Person (Kg)":"Production_per_Person(Kg)"},inplace=True)
df.rename(columns={"Acreage (Hectare)":"Acreage(Hectare)"},inplace=True)
df.rename(columns={"Yield (Kg / Hectare)":"Yield(Kg/Hectare)"},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                   3668531         10226205           75167.5
# 1                    260721          4950000           70393.5
# 2                     88287          1675215           73459.1
# 3                   1264303          1336575           65442.2
# 4                    324219          1130820             57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df[df["Acreage(Hectare)"].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production(Tons) Production_per_Person(Kg)  \
# 99          99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare) Yield(Kg/Hectare)
# 99              NaN               NaN

# %% [markdown]
# ## reseting the index after dropping the null values

# %%
df=df.dropna().reset_index()

# %%
df.isna().sum()
# Out:
# index                        0
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare)             0
# Yield(Kg/Hectare)            0
# dtype: int64

# %%
df.shape
# Out:
# (102, 8)

# %% [markdown]
# ## drop the coloumn unnamed

# %%
df.drop(["index","Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production(Tons) Production_per_Person(Kg)  \
# 0    Brazil  South America        768678382                   3668531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                   1264303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_Person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df["Production(Tons)"]=df["Production(Tons)"].astype(float)
df["Production_per_Person(Kg)"]=df["Production_per_Person(Kg)"].astype(float)
df["Acreage(Hectare)"]=df["Acreage(Hectare)"].astype(float)
df["Yield(Kg/Hectare)"]=df["Yield(Kg/Hectare)"].astype(float)

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_Person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                  3668531.0
# 1     India           Asia       348448000.0                   260721.0
# 2     China           Asia       123059739.0                    88287.0
# 3  Thailand           Asia        87468496.0                  1264303.0
# 4  Pakistan           Asia        65450704.0                   324219.0
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# ## to show how many different values lie in the continent coloumns

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production(Tons)"])
plt.subplot(2,2,2)
sns.distplot(df["Production_per_Person(Kg)"])
plt.subplot(2,2,3)
sns.distplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.distplot(df["Yield(Kg/Hectare)"])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5052\1619783291.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production(Tons)"])
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5052\1619783291.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df["Production(Tons)"])
plt.subplot(2,2,2)
sns.boxplot(df["Production_per_Person(Kg)"])
plt.subplot(2,2,3)
sns.boxplot(df["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.boxplot(df["Yield(Kg/Hectare)"])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02               1.020000e+02      1.020000e+02
# mean       1.850372e+07               4.124805e+05      2.498981e+05
# std        8.419149e+07               8.669140e+05      1.137003e+06
# min        1.000000e+00               0.000000e+00      0.000000e+00
# 25%        6.251875e+04               1.075225e+04      1.104000e+03
# 50%        1.440044e+06               8.135850e+04      1.655800e+04
# 75%        6.426824e+06               2.828128e+05      8.047400e+04
# max        7.686784e+08               4.816299e+06      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# # Bivariate-Analysis

# %%
df_new=df[["Country","Production(Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production(Tons)_percent"]=df_new["Production(Tons)"]*100/df_new["Production(Tons)"].sum()

# %%
df_new
# Out:
#            Production(Tons)  Production(Tons)_percent
# Country
# Brazil          768678382.0              4.072729e+01
# India           348448000.0              1.846200e+01
# China           123059739.0              6.520138e+00
# Thailand         87468496.0              4.634389e+00
# Pakistan         65450704.0              3.467809e+00
# ...                     ...                       ...
# Spain                 394.0              2.087551e-05
# Lebanon                97.0              5.139401e-06
# Singapore              50.0              2.649176e-06
# Samoa                  12.0              6.358022e-07
# Syria                   1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production(Tons)_percent"].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df_new["Production(Tons)_percent"].head(15).plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df_new["Production(Tons)"].head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ## rotating the tags of x-axis by 90

# %%
ax=sns.barplot(data=df.head(10),x="Country",y="Production(Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ###  plotting the data with highest land area (sort the data before plotting)

# %%
df_acr=df.sort_values("Acreage(Hectare)",ascending=False)
ax=sns.barplot(data=df_acr.head(10),x="Country",y="Acreage(Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %%
df_yeild=df.sort_values("Yield(Kg/Hectare)",ascending=False)
ax=sns.barplot(data=df_yeild.head(10),x="Country",y="Yield(Kg/Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.352369
# Production_per_Person(Kg)          0.352369                   1.000000
# Acreage(Hectare)                   0.997550                   0.341974
# Yield(Kg/Hectare)                  0.132812                   0.220522
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.132812
# Production_per_Person(Kg)          0.341974           0.220522
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x="Acreage(Hectare)",y="Production(Tons)")
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %%
sns.scatterplot(data=df,x="Yield(Kg/Hectare)",y="Production(Tons)")
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %%
df_cont=df.groupby("Continent").sum()

# %%
df_cont
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                 10144110.0         1439089.0
# Asia                721930425.0                  3120808.0        10608319.0
# Europe                   5823.0                      536.0              71.0
# North America       173995947.0                 15420953.0         1581983.0
# Oceania              36177574.0                  3158066.0          490909.0
# ...

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df_cont["Production(Tons)"].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df_cont["num_of_country"]=df.groupby("Continent").count()["Country"]

# %%
df_cont
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                 10144110.0         1439089.0
# Asia                721930425.0                  3120808.0        10608319.0
# Europe                   5823.0                      536.0              71.0
# North America       173995947.0                 15420953.0         1581983.0
# Oceania              36177574.0                  3158066.0          490909.0
# ...

# %%
cont_names=df_cont.index.to_list()
sns.lineplot(data=df_cont,x="num_of_country",y="Production(Tons)")
plt.xticklabel(df_cont["num_of_country"],continent_names,rotation=90)
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[215], line 3
#       1 cont_names=df_cont.index.to_list()
#       2 sns.lineplot(data=df_cont,x="num_of_country",y="Production(Tons)")
# ----> 3 plt.xticklabel(df_cont["num_of_country"],continent_names,rotation=90)
#       4 plt.show()
#
# ...

# %%
df_cont.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.143100
# Production_per_Person(Kg)          0.143100                   1.000000
# Acreage(Hectare)                   0.994897                   0.073059
# Yield(Kg/Hectare)                  0.091201                   0.541229
# num_of_country                     0.109244                   0.526387
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  num_of_country
# Production(Tons)                   0.994897           0.091201        0.109244
# Production_per_Person(Kg)          0.073059           0.541229        0.526387
# Acreage(Hectare)                   1.000000           0.111166        0.132817
# Yield(Kg/Hectare)                  0.111166           1.000000        0.989712
# num_of_country                     0.132817           0.989712        1.000000

# %%
df_cont["Production(Tons)"].plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Production(Tons)'>
